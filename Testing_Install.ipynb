# %% [markdown]
# # Testing Fresh Install of PyGMT
# Created and tested by A. Newman on 8/23/2022
# * Updated: A. Newman 11/8/2023

# %%
import pygmt
pygmt.show_versions()

fig=pygmt.Figure()
fig.coast(region='g',frame=True, shorelines=1)

fig.show()
# Out:
# PyGMT information:
#   version: v0.10.0
# System information:
#   python: 3.12.0 | packaged by conda-forge | (main, Oct  3 2023, 08:36:57) [Clang 15.0.7 ]
#   executable: /Users/an77/anaconda3/envs/pygmt/bin/python
#   machine: macOS-13.4.1-arm64-arm-64bit
# Dependency information:
#   numpy: 1.26.0
#   pandas: 2.1.2
#   xarray: 2023.10.1
#   netCDF4: 1.6.5
#   packaging: 23.2
#   contextily: None
#   geopandas: None
#   IPython: 8.17.2
#   rioxarray: None
#   ghostscript: 10.01.1
# GMT library information:
#   binary version: 6.4.0
#   cores: 12
#   grid layout: rows
#   image layout:
#   library path: /Users/an77/anaconda3/envs/pygmt/lib/libgmt.dylib
#   padding: 2
#   plugin dir: /Users/an77/anaconda3/envs/pygmt/lib/gmt/plugins
#   share dir: /Users/an77/anaconda3/envs/pygmt/share/gmt
#   version: 6.4.0

# %% [markdown]
# as long as a map shows up, you're good to proceed.
